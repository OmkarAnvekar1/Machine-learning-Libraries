# %%
import numpy as nm 
import matplotlib.pyplot as mtp
import pandas as pd
data_set = pd.read_csv(r"C:\Users\omkar\Downloads\College ML\Salary_Data.csv")
x = data_set.iloc[:, :-1].values
y = data_set.iloc[:, 1].values

#spitting the dataset into training and test set

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

#fitting the simple linear regression model to the training dataset

from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(x_train, y_train)

#prediction of test and training set result
# Access the slope (coefficient) and intercept of the linear regression model

slope = regressor.coef_[0]
intercept = regressor.intercept_

print("Slope (Coefficient):", slope)
print("Intercept:", intercept)
y_pred = regressor.predict(x_test)
x_pred = regressor.predict(x_train)
mtp.scatter(x_train, y_train, color="blue")
mtp.plot(x_train, x_pred, color="black")
mtp.title("Salary vs Experience (Training Dataset)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary(In Rupees)")
mtp.show()
# Out:
# Slope (Coefficient): 9345.942443122372
# Intercept: 26816.192244031183
